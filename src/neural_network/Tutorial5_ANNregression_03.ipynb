# %% [markdown]
# # Regression using Artificial Neural Networks

# %% [markdown]
# using the droped feature data set

# %%
# Import standard Libraries
import pandas as pd
import seaborn as sns
import altair as alt
import tensorflow as tf
import matplotlib.pyplot as plt


pd.set_option('display.float_format', '{:.4f}'.format)

sns.set(rc={'figure.figsize':(10,10)})
print("imports ok")
# Out:
# imports ok

# %% [markdown]
# ##Load Data

# %%
# Load data file
data = pd.read_csv('C:\\Users\\DD\\Desktop\\IAAC\\DATA encoding\\final project_entropy prediction\\data\\processed\\dataset_dropped_features_clean.csv')
pd.options.display.max_columns = None

print(data)
# Out:
#       entropy_normalised  n_3way  n_deadend  proportion_4way  proportion_3way  \
# 0                 0.4445     109          7           0.6037           0.3375
# 1                 0.4290     141          5           0.1913           0.7705
# 2                 0.3901      72          0           0.6838           0.2846
# 3                 0.4223     115          8           0.6618           0.2798
# 4                 0.3950     111          3           0.6798           0.2913
# ...                  ...     ...        ...              ...              ...
# 2495              0.9459     112         49           0.1043           0.5308
# 2496              0.9715      80         12           0.4408           0.3791
# 2497              0.9543     163         15           0.1202           0.6996
# 2498              0.9733     106          9           0.0748           0.7211
# 2499              0.9511      59         15           0.1386           0.5842
#
#       proportion_deadend  mean_edge_length  total_edge_length  circuity  \
# 0                 0.0217           38.8100         22082.5100    1.0066
# 1                 0.0273           26.7800          7659.6200    1.0119
# 2                 0.0000           41.8200         19322.0100    1.0054
# 3                 0.0195           40.5300         30157.7100    1.0137
# 4                 0.0079           41.0500         28486.5900    1.0014
# ...                  ...               ...                ...       ...
# 2495              0.2322           46.2100         12430.8900    1.0359
# 2496              0.0569           52.5400         17914.6200    1.0201
# 2497              0.0644           49.4900         16579.5800    1.0845
# 2498              0.0612           59.7400         12426.8200    1.1307
# 2499              0.1485           71.4100          9783.0800    1.0407
#
#       distance_to_center_km
# 0                   20.0430
# 1                    5.7660
# 2                   15.5970
# 3                   13.4270
# 4                   16.7120
# ...                     ...
# 2495                 3.0830
# 2496                 7.2640
# 2497                 6.1210
# 2498                11.2080
# 2499                 6.8840
#
# [2500 rows x 10 columns]

# %%
print(data.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   entropy_normalised     2500 non-null   float64
#  1   n_3way                 2500 non-null   int64
#  2   n_deadend              2500 non-null   int64
#  3   proportion_4way        2500 non-null   float64
#  4   proportion_3way        2500 non-null   float64
#  5   proportion_deadend     2500 non-null   float64
#  6   mean_edge_length       2500 non-null   float64
#  7   total_edge_length      2500 non-null   float64
#  8   circuity               2500 non-null   float64
#  9   distance_to_center_km  2500 non-null   float64
# dtypes: float64(8), int64(2)
# memory usage: 195.4 KB
# None

# %%
for colname, col in data.items():
  print(colname, "min_val", col.min(), "max_val", col.max())
# Out:
# entropy_normalised min_val 0.383996 max_val 0.992793
# n_3way min_val 9 max_val 881
# n_deadend min_val 0 max_val 449
# proportion_4way min_val 0.0 max_val 0.747922
# proportion_3way min_val 0.115385 max_val 0.916667
# proportion_deadend min_val 0.0 max_val 0.557692
# mean_edge_length min_val 16.86 max_val 165.62
# total_edge_length min_val 701.87 max_val 39750.52
# circuity min_val 0.998254 max_val 1.445991
# distance_to_center_km min_val 0.319 max_val 78.188

# %%
data.describe()
# Out:
#        entropy_normalised    n_3way  n_deadend  proportion_4way  \
# count           2500.0000 2500.0000  2500.0000        2500.0000
# mean               0.6921  105.0856    34.4676           0.2156
# std                0.1737   85.6122    37.0734           0.1777
# min                0.3840    9.0000     0.0000           0.0000
# 25%                0.5414   47.0000    12.0000           0.0833
# 50%                0.6901   86.0000    23.0000           0.1634
# 75%                0.8471  137.0000    43.2500           0.2926
# max                0.9928  881.0000   449.0000           0.7479
#
#        proportion_3way  proportion_deadend  mean_edge_length  \
# count        2500.0000           2500.0000         2500.0000
# mean            0.4949              0.1785           56.6371
# std             0.1171              0.1077           20.8052
# min             0.1154              0.0000           16.8600
# 25%             0.4231              0.0949           40.5900
# 50%             0.5000              0.1667           52.0350
# 75%             0.5735              0.2500           67.6125
# max             0.9167              0.5577          165.6200
#
#        total_edge_length  circuity  distance_to_center_km
# count          2500.0000 2500.0000              2500.0000
# mean          14225.2829    1.0494                12.3641
# std            7873.8953    0.0500                10.3391
# min             701.8700    0.9983                 0.3190
# 25%            8223.5825    1.0164                 5.8603
# 50%           12638.5000    1.0366                 9.7740
# 75%           19096.2925    1.0640                14.7272
# max           39750.5200    1.4460                78.1880

# %%
print(data.columns.tolist())
# Out:
# ['entropy_normalised', 'n_3way', 'n_deadend', 'proportion_4way', 'proportion_3way', 'proportion_deadend', 'mean_edge_length', 'total_edge_length', 'circuity', 'distance_to_center_km']

# %% [markdown]
# we can see that some predictors are binary, while others are not

# %%
feature_cols = ['n_3way', 'n_deadend', 'proportion_4way', 'proportion_3way',
                'proportion_deadend', 'mean_edge_length', 'total_edge_length',
                'circuity', 'distance_to_center_km']



print("Features:", feature_cols)
print("Target: entropy_normalised")
data[feature_cols].describe()
# Out:
# Features: ['n_3way', 'n_deadend', 'proportion_4way', 'proportion_3way', 'proportion_deadend', 'mean_edge_length', 'total_edge_length', 'circuity', 'distance_to_center_km']
# Target: entropy_normalised
#          n_3way  n_deadend  proportion_4way  proportion_3way  \
# count 2500.0000  2500.0000        2500.0000        2500.0000
# mean   105.0856    34.4676           0.2156           0.4949
# std     85.6122    37.0734           0.1777           0.1171
# min      9.0000     0.0000           0.0000           0.1154
# 25%     47.0000    12.0000           0.0833           0.4231
# 50%     86.0000    23.0000           0.1634           0.5000
# 75%    137.0000    43.2500           0.2926           0.5735
# max    881.0000   449.0000           0.7479           0.9167
#
#        proportion_deadend  mean_edge_length  total_edge_length  circuity  \
# count           2500.0000         2500.0000          2500.0000 2500.0000
# mean               0.1785           56.6371         14225.2829    1.0494
# std                0.1077           20.8052          7873.8953    0.0500
# min                0.0000           16.8600           701.8700    0.9983
# 25%                0.0949           40.5900          8223.5825    1.0164
# 50%                0.1667           52.0350         12638.5000    1.0366
# 75%                0.2500           67.6125         19096.2925    1.0640
# max                0.5577          165.6200         39750.5200    1.4460
#
#        distance_to_center_km
# count              2500.0000
# mean                 12.3641
# std                  10.3391
# min                   0.3190
# 25%                   5.8603
# 50%                   9.7740
# 75%                  14.7272
# max                  78.1880

# %%
data_numerical = data[['entropy_normalised', 'mean_edge_length', 'total_edge_length', 'circuity']]
sns.pairplot(data_numerical)

# %% [markdown]
# We can see there is a direct relationship between age and experience, but not so much between wage and education, there is a non-linearity

# %% [markdown]
# ##Prepare Data

# %% [markdown]
# **NORMALIZE INPUTS**

# %%
#same code as last time

feature_cols = ['n_3way', 'n_deadend', 'proportion_4way', 'proportion_3way',
                'proportion_deadend', 'mean_edge_length', 'total_edge_length',
                'circuity', 'distance_to_center_km']



X = data[feature_cols].to_numpy()

from sklearn.preprocessing import StandardScaler
scalerX = StandardScaler()

X_scaled = scalerX.fit_transform(X)

print(X_scaled.shape)
# Out:
# (2500, 9)

# %%
#declare regression target
y = data.loc[:, "entropy_normalised"].to_numpy()

y = y.reshape(-1, 1)

from sklearn.preprocessing import MinMaxScaler
scalerY = MinMaxScaler()

# Apply the scaler to our Y-features
y_scaled = scalerY.fit_transform(y)

print(y_scaled.shape)
# Out:
# (2500, 1)

# %% [markdown]
# **SPLIT INTO TRAIN AND TEST**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size = 0.2, random_state = 21)

# %%
#visualize our data
#we can see that scikitlearn doesnt care if it is a dataframe or a numpy array, because they all function on the same way
print("TRAIN", "input", X_train.shape, "output", y_train.shape)
print("TEST", "input", X_test.shape, "output", y_test.shape)
# Out:
# TRAIN input (2000, 9) output (2000, 1)
# TEST input (500, 9) output (500, 1)

# %% [markdown]
# #Build model

# %% [markdown]
# From the cheatSheet
# Regression between 0 and 1>>
#       activation = relu for hidden layers / sigmoid for final layer
#       loss = mean squared error
#       optimizer = adam
#       input from data, is 8 columns
#       output is 1 value prediction

# %%
# Instantiate a sequential model
model = tf.keras.models.Sequential()
n_cols = X_scaled.shape[1]

model.add(tf.keras.layers.Input(shape=(n_cols,)))
model.add(tf.keras.layers.Dense(10, activation='relu'))   # 9×10+10  = 100
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(8, activation='relu'))    # 10×8+8   = 88
model.add(tf.keras.layers.Dense(1, activation='linear'))  # 8×1+1    = 9

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001, clipnorm=1.0),
              loss='mean_squared_error')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 32)             │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 18)             │           594 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            19 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,989 (7.77 KB)
#  Trainable params: 1,989 (7.77 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #Train model

# %%
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs=500, validation_split=0.2, callbacks=[early_stop])
# Out:
# Epoch 1/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2355 - val_loss: 0.0872
# Epoch 2/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1054 - val_loss: 0.0675
# Epoch 3/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0859 - val_loss: 0.0573
# Epoch 4/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0696 - val_loss: 0.0530
# Epoch 5/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0635 - val_loss: 0.0512
# Epoch 6/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0612 - val_loss: 0.0507
# Epoch 7/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0581 - val_loss: 0.0497
# Epoch 8/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0554 - val_loss: 0.0460
# Epoch 9/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0548 - val_loss: 0.0468
# Epoch 10/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0538 - val_loss: 0.0494
# Epoch 11/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0528 - val_loss: 0.0469
# Epoch 12/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0503 - val_loss: 0.0464
# Epoch 13/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0516 - val_loss: 0.0484
# Epoch 14/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0494 - val_loss: 0.0460
# Epoch 15/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0485 - val_loss: 0.0453
# Epoch 16/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0472 - val_loss: 0.0465
# Epoch 17/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0470 - val_loss: 0.0452
# Epoch 18/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0470 - val_loss: 0.0458
# Epoch 19/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0480 - val_loss: 0.0443
# Epoch 20/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0465 - val_loss: 0.0445
# Epoch 21/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0472 - val_loss: 0.0447
# Epoch 22/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0456 - val_loss: 0.0446
# Epoch 23/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0463 - val_loss: 0.0443
# Epoch 24/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0459 - val_loss: 0.0434
# Epoch 25/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0456 - val_loss: 0.0440
# Epoch 26/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0453 - val_loss: 0.0445
# Epoch 27/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0448 - val_loss: 0.0447
# Epoch 28/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0453 - val_loss: 0.0444
# Epoch 29/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0458 - val_loss: 0.0460
# Epoch 30/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0432 - val_loss: 0.0438
# Epoch 31/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0436 - val_loss: 0.0439
# Epoch 32/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0448 - val_loss: 0.0437
# Epoch 33/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0436 - val_loss: 0.0435
# Epoch 34/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0437 - val_loss: 0.0435
# Epoch 35/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0429 - val_loss: 0.0434
# Epoch 36/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0455 - val_loss: 0.0437
# Epoch 37/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0432 - val_loss: 0.0433
# Epoch 38/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0424 - val_loss: 0.0442
# Epoch 39/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0424 - val_loss: 0.0455
# Epoch 40/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0429 - val_loss: 0.0437
# Epoch 41/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0414 - val_loss: 0.0440
# Epoch 42/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0424 - val_loss: 0.0438
# Epoch 43/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0424 - val_loss: 0.0431
# Epoch 44/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0406 - val_loss: 0.0431
# Epoch 45/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0428 - val_loss: 0.0432
# Epoch 46/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0420 - val_loss: 0.0433
# Epoch 47/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0429 - val_loss: 0.0427
# Epoch 48/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0409 - val_loss: 0.0431
# Epoch 49/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0414 - val_loss: 0.0431
# Epoch 50/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0422 - val_loss: 0.0427
# Epoch 51/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0409 - val_loss: 0.0437
# Epoch 52/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0412 - val_loss: 0.0435
# Epoch 53/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0407 - val_loss: 0.0435
# Epoch 54/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0405 - val_loss: 0.0437
# Epoch 55/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0403 - val_loss: 0.0434
# Epoch 56/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0408 - val_loss: 0.0435
# Epoch 57/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0405 - val_loss: 0.0426
# Epoch 58/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0410 - val_loss: 0.0422
# Epoch 59/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0417 - val_loss: 0.0426
# Epoch 60/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0410 - val_loss: 0.0427
# Epoch 61/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0416 - val_loss: 0.0424
# Epoch 62/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0399 - val_loss: 0.0425
# Epoch 63/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0407 - val_loss: 0.0430
# Epoch 64/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0403 - val_loss: 0.0429
# Epoch 65/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0405 - val_loss: 0.0425
# Epoch 66/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0397 - val_loss: 0.0426
# Epoch 67/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0405 - val_loss: 0.0440
# Epoch 68/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0395 - val_loss: 0.0436
# Epoch 69/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0408 - val_loss: 0.0431
# Epoch 70/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0381 - val_loss: 0.0432
# Epoch 71/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0406 - val_loss: 0.0430
# Epoch 72/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0389 - val_loss: 0.0423
# Epoch 73/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0391 - val_loss: 0.0428
# Epoch 74/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0398 - val_loss: 0.0433
# Epoch 75/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0389 - val_loss: 0.0439
# Epoch 76/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0386 - val_loss: 0.0428
# Epoch 77/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0398 - val_loss: 0.0430
# Epoch 78/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0396 - val_loss: 0.0436
# Epoch 79/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0390 - val_loss: 0.0437
# Epoch 80/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0395 - val_loss: 0.0432
# Epoch 81/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0391 - val_loss: 0.0437
# Epoch 82/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0386 - val_loss: 0.0428
# Epoch 83/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0379 - val_loss: 0.0431
# Epoch 84/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0391 - val_loss: 0.0424
# Epoch 85/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0395 - val_loss: 0.0428
# Epoch 86/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0379 - val_loss: 0.0432
# Epoch 87/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0386 - val_loss: 0.0431
# Epoch 88/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0385 - val_loss: 0.0443

# %%
# summarize history for accuracy
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('loss function')
plt.ylabel('mse')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# #Evaluate model on test data

# %%
# Evaluate your model accuracy on the test data
loss_test = model.evaluate(X_test,y_test)

# Print accuracy
print('mse_test:', loss_test)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0396
# mse_test: 0.03959087282419205

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_truth, y_pred)
print(f'R² score: {r2:.4f}  →  model explains {r2*100:.1f}% of the variance')
# Out:
# R² score: 0.4814  →  model explains 48.1% of the variance

# %% [markdown]
# #Plot error

# %%
y_pred = scalerY.inverse_transform(model.predict(X_test))
y_truth = scalerY.inverse_transform(y_test)

plt.scatter(y_truth, y_pred)
plt.ylim((0, 1))
plt.xlim((0, 1))
plt.axline((0, 0), slope=1, ls="--")

plt.xlabel("y_truth (entropy normalised)")
plt.ylabel("y_pred (entropy normalised)")
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Text(0, 0.5, 'y_pred (entropy normalised)')

# %%
def plot_comparison(x_val, pred, truth, xlab, ylab):
  fig, ax1 = plt.subplots(figsize = (10,10))
  ax1.plot(x_val, truth, color = "red", label = "truth",linestyle='None', marker = "o", markersize = 5)
  ax1.plot(x_val, pred, color = "blue", label = "pred",linestyle='None', marker = "o", markersize = 4, alpha = 0.5)

  ax1.set_xlabel(xlab)
  ax1.set_ylabel(ylab)
  ax1.legend()
  plt.title('Prediction Comparison')
  plt.show()

# %%
mean_edge_test = scalerX.inverse_transform(X_test)[:, feature_cols.index('mean_edge_length')]
circuity_test = scalerX.inverse_transform(X_test)[:, feature_cols.index('circuity')]

plot_comparison(mean_edge_test, y_pred, y_truth, "mean edge length", "entropy normalised")
plot_comparison(circuity_test, y_pred, y_truth, "circuity", "entropy normalised")

# %%
error = y_pred - y_truth
plt.hist(error, bins=25)
plt.xlabel('Prediction Error [entropy normalised]')
_ = plt.ylabel('Count')

# %%
model.save('ANNregression_02.keras')

import pickle
pickle.dump(scalerX, open('scalerX.pkl', 'wb'))
pickle.dump(scalerY, open('scalerY.pkl', 'wb'))

print("Model and scalers saved!")
# Out:
# Model and scalers saved!
